# %% [markdown]
# # 1. Limpieza de Datos

# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv('data/titanic_clean.csv')
#objeto df (data frame: suma de columnas o series = tabla), read es un método de pandas, csv es el formato del archivo, y entre paréntesis va la ruta del archivo a leer. En este caso, el archivo se llama titanic_clean.csv y se encuentra en la carpeta data. El resultado de esta línea de código es un DataFrame de pandas que contiene los datos del archivo CSV.

# %%
df.head() #muestras las primeras 5 filas del DataFrame. Es útil para obtener una vista rápida de los datos y verificar que se han cargado correctamente. Si quieres mostrar un número diferente de filas, puedes pasar un argumento a head(), por ejemplo df.head(10) mostrará las primeras 10 filas.
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
print("Valores nulos por columna")
print(df.isnull().sum())
# Out:
# Valores nulos por columna
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %% [markdown]
# # Tratamiento de Nulos

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])


df_clean.to_csv('data/titanic_clean.csv', index=False)
print("Datos guardados en data/titanic_clean.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       1 df['Age'] = df['Age'].fillna(df['Age'].median())
#       2 df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])
#       3
#       4
# ----> 5 df_clean.to_csv('data/titanic_clean.csv', index=False)
#       6 print("Datos guardados en data/titanic_clean.csv")
#
# NameError: name 'df_clean' is not defined
